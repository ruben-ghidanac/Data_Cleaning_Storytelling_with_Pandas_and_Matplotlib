# %%
import pandas as pd

# %% [markdown]
# ### Orders

# %%
# orders.csv
path = "C:/Users/ruben/local_repos/WBS/Data_Science/Section_3/Data_Cleaning_Storytelling_with_Pandas_and_Matplotlib/data/raw_data/orders.csv"
orders = pd.read_csv(path)

# %% [markdown]
# I'm looking for null values and data types.

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226909 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226909 non-null  int64
#  1   created_date  226909 non-null  object
#  2   total_paid    226904 non-null  float64
#  3   state         226909 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 6.9+ MB

# %% [markdown]
# Look's like 'total_paid' has 5 rows with null values and, 'created_date' Dtype needs to be changed.

# %%
orders["created_date"] = pd.to_datetime(orders["created_date"])

# %%
nan_count = orders.isna().sum()
nan_count_sum = nan_count.sum()

print(f"{nan_count_sum} missing values represents {((orders.total_paid.isna().sum() / orders.shape[0])*100).round(5)}% of the rows in our DataFrame")
# Out:
# 5 missing values represents 0.0022% of the rows in our DataFrame

# %%
# create a boolean mask indicating which values are NaN
mask = orders.isna()

# use the mask to filter the dataframe
na_rows = orders[mask.any(axis=1)]

print(na_rows)
# Out:
#         order_id        created_date  total_paid    state
# 127701    427314 2017-11-20 18:54:39         NaN  Pending
# 132013    431655 2017-11-22 12:15:24         NaN  Pending
# 147316    447411 2017-11-27 10:32:37         NaN  Pending
# 148833    448966 2017-11-27 18:54:15         NaN  Pending
# 149434    449596 2017-11-27 21:52:08         NaN  Pending

# %% [markdown]
# Now we know which rows are bad, and details about that orders, some important one are 'created_date' and 'state'.

# %% [markdown]
# Let's figure it out for how long they are in 'pending' state.

# %%
first_order = orders["created_date"].min()
last_order = orders["created_date"].max()

# %%
total_period_time = orders["created_date"].max() - orders["created_date"].min()

# %%
print("This is the first created_date order: ")
first_order
# Out:
# This is the first created_date order:
# Timestamp('2017-01-01 00:07:19')

# %%
print("This is the last created_date order: ")
last_order
# Out:
# This is the last created_date order:
# Timestamp('2018-03-14 13:58:36')

# %%
# Total time in 'pending' state for the orders with 'NaN' total_paid value
from datetime import datetime

timestamps = na_rows['created_date']
timedeltas = []

for timestamp in timestamps:
    timedeltas.append(last_order - timestamp)

timedeltas
# Out:
# [Timedelta('113 days 19:03:57'),
#  Timedelta('112 days 01:43:12'),
#  Timedelta('107 days 03:25:59'),
#  Timedelta('106 days 19:04:21'),
#  Timedelta('106 days 16:06:28')]

# %% [markdown]
# We can drop them, without regrets, because they are in that state of 'pending' for an unusual long period of time, and also, the missing values represents only 0.0022% of the rows in our DataFrame.

# %%
orders = orders.dropna()

# %%
nan_count = orders.isna().sum()
nan_count = nan_count.sum()
nan_count

print(f"{nan_count} missing values represents {((orders.total_paid.isna().sum() / orders.shape[0])*100).round(5)}% of the rows in our DataFrame")
# Out:
# 0 missing values represents 0.0% of the rows in our DataFrame

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 226904 entries, 0 to 226908
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   order_id      226904 non-null  int64
#  1   created_date  226904 non-null  datetime64[ns]
#  2   total_paid    226904 non-null  float64
#  3   state         226904 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 8.7+ MB

# %% [markdown]
# Everything look's nice and clean.

# %% [markdown]
# ### Orderlines

# %%
# orderlines.csv
path = "C:/Users/ruben/local_repos/WBS/Data_Science/Section_3/Data_Cleaning_Storytelling_with_Pandas_and_Matplotlib/data/raw_data/orderlines.csv"
orderlines = pd.read_csv(path)

# %% [markdown]
# I'm looking for null values and data types.

# %%
orderlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  object
#  6   date              293983 non-null  object
# dtypes: int64(4), object(3)
# memory usage: 15.7+ MB

# %% [markdown]
# Must be modified 'date' and 'unit_price'.

# %%
orderlines["date"] = pd.to_datetime(orderlines["date"])

# %%
orderlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  object
#  6   date              293983 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 15.7+ MB

# %% [markdown]
# Now let's focus on 'unit_price'.

# %% [markdown]
# If you will run the line of code below, you will have this error: 'ValueError: Unable to parse string "1.137.99" at position 6'.

# %%
#orderlines["unit_price"] = pd.to_numeric(orderlines["unit_price"])

# %% [markdown]
# We need to create a function that keep only the last decimal point, which is the good one.

# %%
import re
def fix_two_dot(price):
  # Use a regex to find a string with two dots and capture the first and last parts of the string
  result = re.search(r'^(\d+)\.(\d+)\.(\d+)$', price)
  if result:
    # If a match is found, concatenate the captured groups and return the result
    return result.group(1) + result.group(2) + '.' + result.group(3)
  else:
    # If no match is found, return the original string
    return price

# %%
# Apply the custom function to the unit_price column
orderlines['unit_price'] = orderlines['unit_price'].apply(fix_two_dot)

# %% [markdown]
# Let's verify how many rows still have this 'two_dot' problem.

# %%
orderlines.loc[orderlines.unit_price.str.contains("\d+\.\d+\.\d+")]
# Out:
# Empty DataFrame
# Columns: [id, id_order, product_id, product_quantity, sku, unit_price, date]
# Index: []

# %% [markdown]
# Look's like the problem was solved.
#
# Let's verify the position 6 in dataframe, because of our last error: 'ValueError: Unable to parse string "1.137.99" at position 6'

# %%
orderlines.iloc[6]
# Out:
# id                              1119115
# id_order                         299544
# product_id                            0
# product_quantity                      1
# sku                             APP1582
# unit_price                      1137.99
# date                2017-01-01 01:17:21
# Name: 6, dtype: object

# %% [markdown]
# Now must working nice and smooth 'pd.to_numeric' function applied to 'unit_price'.

# %%
orderlines["unit_price"] = pd.to_numeric(orderlines["unit_price"])

# %%
orderlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293983 entries, 0 to 293982
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                293983 non-null  int64
#  1   id_order          293983 non-null  int64
#  2   product_id        293983 non-null  int64
#  3   product_quantity  293983 non-null  int64
#  4   sku               293983 non-null  object
#  5   unit_price        293983 non-null  float64
#  6   date              293983 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(1)
# memory usage: 15.7+ MB

# %% [markdown]
# Everything look's nice and clean.

# %% [markdown]
# ### Products

# %%
# products.csv
path = "C:/Users/ruben/local_repos/WBS/Data_Science/Section_3/Data_Cleaning_Storytelling_with_Pandas_and_Matplotlib/data/raw_data/products.csv"
products = pd.read_csv(path)

# %% [markdown]
# I'm looking for null values and data types.

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19326 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19326 non-null  object
#  1   name         19326 non-null  object
#  2   desc         19319 non-null  object
#  3   price        19280 non-null  object
#  4   promo_price  19326 non-null  object
#  5   in_stock     19326 non-null  int64
#  6   type         19276 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.0+ MB

# %% [markdown]
# Look's like we only need to change the Dtype of 'price' and 'promo_price'.

# %% [markdown]
# Let's have a closer look.

# %%
products.head(20)
# Out:
#           sku                                               name  \
# 0     RAI0007                  Silver Rain Design mStand Support
# 1     APP0023                  Apple Mac Keyboard Keypad Spanish
# 2     APP0025                   Mighty Mouse Apple Mouse for Mac
# 3     APP0072      Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007        Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# 5     APP0073     Apple Composite AV Cable iPhone and iPod white
# 6     KIN0008        Mac Memory Kingston 1GB 667MHz DDR2 SO-DIMM
# 7     KIN0009        Mac Memory Kingston 2GB 800MHz DDR2 SO-DIMM
# 8   KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
# 9     APP0100             Apple Adapter Mini Display Port to VGA
# 10    APP0101              Apple Mini DisplayPort to DVI Adapter
# 11    SEN0021  Sennheiser CX 300-II Precision headphones iPho...
# 12    APP0111                     Apple USB Ethernet Adapter Mac
# 13    APP0156              45W MagSafe charger Apple MacBook Air
# 14    MOS0013         Adapter Moshi FireWire 400 to FireWire 800
# 15    MOS0021               Clearguard Moshi MacBook Pro and Air
# 16    APP0206  60W MagSafe charger Apple MacBook and MacBook ...
# 17    HGD0007       Henge Docks Docking Station MacBook Pro 13 "
# 18    MUV0009    Muvit Back Clear Case iPhone 4 / 4S Transparent
# 19    APP0234                        Apple Dock Connector to VGA
#
#                                                  desc  price promo_price  \
# 0        Aluminum support compatible with all MacBook  59.99     499.899
# 1           USB ultrathin keyboard Apple Mac Spanish.     59     589.996
# 2                              mouse Apple USB cable.     59     569.898
# 3               IPhone dock and USB Cable Apple iPod.     25     229.997
# 4   2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99       31.99
# 5   IPhone and iPod AV Cable Dock to Composite Video.     45     420.003
# 6   1GB RAM Mac mini and iMac (2006/07) MacBook Pr...  18.99     146.471
# 7        2GB RAM iMac with Intel Core 2 Duo (Penryn).  36.99     274.694
# 8   RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...     74     669.904
# 9   Adapter Mini Display Port to VGA MacBook and M...     35     330.003
# 10  Adapter mini DisplayPort to DVI MacBook and Ma...     35     330.003
# 11     Headphones iPhone iPad iPad 2 iPad 3 and iPod.  49.99     449.878
# 12                       USB to Ethernet adapter Mac.     35     330.003
# 13     Charger MacBook Air MagSafe 45 W (MC747Z / A).     89     849.904
# 14           FireWire 400 adapter cable FireWire 800.     20     179.891
# 15  Keyboard Protector MacBook Pro 13-inch Retina ...  24.95     249.889
# 16  Charger MacBook and 13 inch MacBook MagSafe 60...     89     849.904
# 17  Dock and support with multiple connections for...  69.99     699.864
# 18                  Case iPhone 4 / 4S polycarbonate.   9.99       7.986
# 19                         Dock Connector to VGA IOS.     35     350.005
#
#     in_stock      type
# 0          1      8696
# 1          0  13855401
# 2          0      1387
# 3          0      1230
# 4          1      1364
# 5          0      1230
# 6          0      1364
# 7          0      1364
# 8          0      1364
# 9          0      1325
# 10         0      1325
# 11         0      5384
# 12         0      1334
# 13         0  13005399
# 14         0      1325
# 15         0  13835403
# 16         1  13005399
# 17         0  12995397
# 18         0  11865403
# 19         0  13955395

# %% [markdown]
# For the first glanz look's like 'promo_price' need to be fixed.
#
# When 'promo_price' has more characters before his decimal point, compared with 'price', it seems to be only a problem to move the decimal point one position to the left on the 'promo_price' column.

# %% [markdown]
# #### 'promo_price' column

# %% [markdown]
# First let try to solve two dot problem. In case exist, it will be solved.

# %%
products = products.astype({"promo_price": 'str', "price": 'str'})

# %%
# Apply the custom function to the promo_price column
products['promo_price'] = products['promo_price'].apply(fix_two_dot)
products['price'] = products['price'].apply(fix_two_dot)

# %% [markdown]
# Now we can try to to see if we have some 'NaN' values in our dataframe.

# %%
#products['promo_price'] = pd.to_numeric(products['promo_price'])
#products['price'] = pd.to_numeric(products['price'])

# %% [markdown]
# If we try tu run the code above we'll have this error:
#
# 'ValueError: Unable to parse string "nan" at position 34'

# %%
nan_price = products['price'].loc[products['price'] == 'nan'].count()
nan_price
# Out:
# 46

# %%
print(f"The column price has in total {nan_price} 'nan' values. This is {round(((nan_price / products.shape[0]) * 100), 2)}% of the rows of the DataFrame")
# Out:
# The column price has in total 46 'nan' values. This is 0.24% of the rows of the DataFrame

# %% [markdown]
# 0.24% is not too much and more important, the price column will be important to understanding discounts, so I'd like it to be very trustworthy as we are basing business decisions on it. Therefore, we'll delete these rows.

# %%
i = products[products['price'] == 'nan'].index
products = products.drop(i)

# %% [markdown]
# Let's try to move the decimal dot one position to the left

# %%
def modify_promo_price(row):
    price = row['price']
    promo_price = row['promo_price']
    if len(promo_price.split('.')[0]) > len(price.split('.')[0]):
        # Extract the integer and decimal parts of the promo_price
        int_part, dec_part = re.match(r'(\d+)\.(\d+)', promo_price).groups()
        # Reassemble the promo_price with the decimal point moved one place to the left
        magic = len(int_part) - 1
        promo_price = '{}.{}{}'.format(int_part[:magic], int_part[magic:], dec_part[0:])
    return promo_price

# %%
# Apply the custom function to the promo_price column
products['promo_price'] = products.apply(modify_promo_price, axis=1)

# %%
products['promo_price'] = pd.to_numeric(products['promo_price'])
products['price'] = pd.to_numeric(products['price'])

# %%
products.head(20)
# Out:
#           sku                                               name  \
# 0     RAI0007                  Silver Rain Design mStand Support
# 1     APP0023                  Apple Mac Keyboard Keypad Spanish
# 2     APP0025                   Mighty Mouse Apple Mouse for Mac
# 3     APP0072      Apple Dock to USB Cable iPhone and iPod white
# 4     KIN0007        Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# 5     APP0073     Apple Composite AV Cable iPhone and iPod white
# 6     KIN0008        Mac Memory Kingston 1GB 667MHz DDR2 SO-DIMM
# 7     KIN0009        Mac Memory Kingston 2GB 800MHz DDR2 SO-DIMM
# 8   KIN0001-2  Mac memory Kingston 4GB (2x2GB) 667MHz DDR2 SO...
# 9     APP0100             Apple Adapter Mini Display Port to VGA
# 10    APP0101              Apple Mini DisplayPort to DVI Adapter
# 11    SEN0021  Sennheiser CX 300-II Precision headphones iPho...
# 12    APP0111                     Apple USB Ethernet Adapter Mac
# 13    APP0156              45W MagSafe charger Apple MacBook Air
# 14    MOS0013         Adapter Moshi FireWire 400 to FireWire 800
# 15    MOS0021               Clearguard Moshi MacBook Pro and Air
# 16    APP0206  60W MagSafe charger Apple MacBook and MacBook ...
# 17    HGD0007       Henge Docks Docking Station MacBook Pro 13 "
# 18    MUV0009    Muvit Back Clear Case iPhone 4 / 4S Transparent
# 19    APP0234                        Apple Dock Connector to VGA
#
#                                                  desc  price  promo_price  \
# 0        Aluminum support compatible with all MacBook  59.99      49.9899
# 1           USB ultrathin keyboard Apple Mac Spanish.  59.00      58.9996
# 2                              mouse Apple USB cable.  59.00      56.9898
# 3               IPhone dock and USB Cable Apple iPod.  25.00      22.9997
# 4   2GB RAM Mac mini and iMac (2006/07) MacBook Pr...  34.99      31.9900
# 5   IPhone and iPod AV Cable Dock to Composite Video.  45.00      42.0003
# 6   1GB RAM Mac mini and iMac (2006/07) MacBook Pr...  18.99      14.6471
# 7        2GB RAM iMac with Intel Core 2 Duo (Penryn).  36.99      27.4694
# 8   RAM 4GB (2x2GB) Mac mini and iMac (2006/07) Ma...  74.00      66.9904
# 9   Adapter Mini Display Port to VGA MacBook and M...  35.00      33.0003
# 10  Adapter mini DisplayPort to DVI MacBook and Ma...  35.00      33.0003
# 11     Headphones iPhone iPad iPad 2 iPad 3 and iPod.  49.99      44.9878
# 12                       USB to Ethernet adapter Mac.  35.00      33.0003
# 13     Charger MacBook Air MagSafe 45 W (MC747Z / A).  89.00      84.9904
# 14           FireWire 400 adapter cable FireWire 800.  20.00      17.9891
# 15  Keyboard Protector MacBook Pro 13-inch Retina ...  24.95      24.9889
# 16  Charger MacBook and 13 inch MacBook MagSafe 60...  89.00      84.9904
# 17  Dock and support with multiple connections for...  69.99      69.9864
# 18                  Case iPhone 4 / 4S polycarbonate.   9.99       7.9860
# 19                         Dock Connector to VGA IOS.  35.00      35.0005
#
#     in_stock      type
# 0          1      8696
# 1          0  13855401
# 2          0      1387
# 3          0      1230
# 4          1      1364
# 5          0      1230
# 6          0      1364
# 7          0      1364
# 8          0      1364
# 9          0      1325
# 10         0      1325
# 11         0      5384
# 12         0      1334
# 13         0  13005399
# 14         0      1325
# 15         0  13835403
# 16         1  13005399
# 17         0  12995397
# 18         0  11865403
# 19         0  13955395

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19280 entries, 0 to 19325
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sku          19280 non-null  object
#  1   name         19280 non-null  object
#  2   desc         19273 non-null  object
#  3   price        19280 non-null  float64
#  4   promo_price  19280 non-null  float64
#  5   in_stock     19280 non-null  int64
#  6   type         19230 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.2+ MB

# %% [markdown]
# Problem solved.

# %% [markdown]
# ### My curiosity section.

# %% [markdown]
# I want a function that verify each row, if the values of 'promo_price' are grater than 'price' and return True or False for respectively situation.

# %%
def check_price(row):
  # Convert the values in the price and promo_price columns to floats
  price = float(row['price'])
  promo_price = float(row['promo_price'])

  # Check if the promo_price is greater than the price
  if promo_price > price:
    # If it is, return True
    return True
  else:
    # If it is not, return False
    return False

# %%
# Apply the custom function to each row of the dataframe
products['is_promo_price_greater'] = products.apply(check_price, axis=1)

# %% [markdown]
# Verify how much are in that case and how much are not.

# %%
products['is_promo_price_greater'].value_counts()
# Out:
# False    18132
# True      1148
# Name: is_promo_price_greater, dtype: int64

# %%
# the True rate of dataframe
true_count = products['price'][products['is_promo_price_greater'] == True].count() 
total_count = products.shape[0]
true_rate = round(true_count / total_count *100, 2) 

print(f"{true_rate}% of the rows in products.csv, 'promo_price' is grater than 'price'")
# Out:
# 5.95% of the rows in products.csv, 'promo_price' is grater than 'price'

# %% [markdown]
# Hmm, I don't like it. Look's enough weird to make me want to investigate more.

# %%
products.loc[products['is_promo_price_greater'] == True].head(10)
# Out:
#         sku                                            name  \
# 15  MOS0021            Clearguard Moshi MacBook Pro and Air
# 19  APP0234                     Apple Dock Connector to VGA
# 39  JMO0026     Just Mobile Lazy Couch Support Mac and iPad
# 52  BLL0008               BlueLounge CableDrop Pack 6 Black
# 55  BLL0012   Milo BlueLounge support iPhone and iPod white
# 68  MAK0009  Maclocks theft case iPad 2 3 and 4 transparent
# 69  MAK0010        Maclocks theft case iPad 2 3 and 4 black
# 70  MAK0012           Maclocks theft cover Macbook Air 13 "
# 74  SYN0051      Sliding Rail kit synology 2U sliding rails
# 76  WAC0045                Wacom Intuos Airbrush stylus 4/5
#
#                                                  desc   price  promo_price  \
# 15  Keyboard Protector MacBook Pro 13-inch Retina ...   24.95      24.9889
# 19                         Dock Connector to VGA IOS.   35.00      35.0005
# 39                     Mac and iPad small lift stand.   19.95      19.9892
# 52         Cable management Mac iPhone iPad and iPod.   11.99      11.9911
# 55                   Desktop support iPhone and iPod.   14.99      14.9919
# 68  Case antitheft iPad 2 3 and 4 polycarbonate su...   79.99      79.9931
# 69  Case antitheft iPad 2 3 and 4 polycarbonate su...   79.99      79.9931
# 70  Theft Case MacBook Air 13-inch polycarbonate w...   79.99      79.9931
# 74               Shelf rail kit Synology RackStation.  102.49     929.8850
# 76  stylus for pen tablets Cintiq 21UX Intuos 4/5 ...  109.90     999.9440
#
#     in_stock      type  is_promo_price_greater
# 15         0  13835403                    True
# 19         0  13955395                    True
# 39         0      8696                    True
# 52         0  12285400                    True
# 55         0      1216                    True
# 68         0  12635403                    True
# 69         0  12635403                    True
# 70         0  13835403                    True
# 74         0      1404                    True
# 76         0      1229                    True

# %% [markdown]
# Look's like for some of them is only a decimal dot problem.
#
# Let's try to solve it and see what we have after that.
#
# I want to create a function that calculates with how much is 'promo_price' grater than 'price'.

# %%
def promo_greater_with(row):
    if row['promo_price'] > row['price']:
        return row['promo_price'] - row['price']
    else:
        return 0

# %%
products['promo_greater_with'] = products.apply(promo_greater_with, axis=1)

# %%
products.nlargest(100, 'promo_greater_with')
# Out:
#              sku                                               name  \
# 18431    APP2662  Apple iMac Pro 27 "10-core Intel Xeon 3GHz W |...
# 18426    APP2657  Apple iMac Pro 27 "8-core Intel Xeon W 32GHz |...
# 18449    APP2680  Apple iMac Pro 27 "18-core Intel Xeon W 23GHz ...
# 18451    APP2682  Apple iMac Pro 27 "10-core Intel Xeon 3GHz W |...
# 18475    APP2706  Apple iMac Pro 27 "14-core Intel Xeon W 25GHz ...
# ...          ...                                                ...
# 11180    PAC1646       QNAP TS-253A | 8GB RAM | 16TB (2x8TB) WD Red
# 11181    PAC1646       QNAP TS-253A | 8GB RAM | 16TB (2x8TB) WD Red
# 16941  APP1575-A  Open - Apple MacBook Air 13 "i5 16 Ghz | 8GB R...
# 11026    PAC1301  Pack QNAP TS-451 + | 2GB RAM | Seagate 16TB Ir...
# 11027    PAC1301  Pack QNAP TS-451 + | 2GB RAM | Seagate 16TB Ir...
#
#                                                     desc     price  \
# 18431  Pro iMac 27 inch screen Retina 5K and Intel Xe...  10539.00
# 18426  Pro iMac 27 inch screen Retina 5K and Intel Xe...  10539.00
# 18449  Pro iMac 27 inch screen Retina 5K and Intel Xe...  10299.00
# 18451  Pro iMac 27 inch screen Retina 5K and Intel Xe...  10299.00
# 18475  Pro iMac 27 inch screen Retina 5K and Intel Xe...  10299.00
# ...                                                  ...       ...
# 11180  NAS 8GB memory RAM + 16TB (2x8TB) Seagate Hard...   1217.99
# 11181  NAS 8GB memory RAM + 16TB (2x8TB) Seagate Hard...   1217.99
# 16941  Laptop MacBook Air 13 inch i5 128GB RAM 8GB Fl...   1099.00
# 11026  Pack QNAP TS-251 + with 2GB RAM + 16TB (4x4TB)...   1198.95
# 11027  Pack QNAP TS-251 + with 2GB RAM + 16TB (4x4TB)...   1198.95
#
#        promo_price  in_stock       type  is_promo_price_greater  \
# 18431    99071.134         0  118692158                    True
# 18426    99070.045         0  118692158                    True
# 18449    96810.043         0  118692158                    True
# 18451    96810.043         0  118692158                    True
# 18475    96810.043         0  118692158                    True
# ...            ...       ...        ...                     ...
# 11180     9281.789         0   12175397                    True
# 11181     9281.789         0   12175397                    True
# 16941     9146.874         0       1298                    True
# 11026     9223.685         0   12175397                    True
# 11027     9223.685         0   12175397                    True
#
#        promo_greater_with
# 18431           88532.134
# 18426           88531.045
# 18449           86511.043
# 18451           86511.043
# 18475           86511.043
# ...                   ...
# 11180            8063.799
# 11181            8063.799
# 16941            8047.874
# 11026            8024.735
# 11027            8024.735
#
# [100 rows x 9 columns]

# %% [markdown]
# Look's like for some of them is still a decimal problem.
#
# I want to order them, and reach more insights.

# %%
sorted_products = products.copy()
sorted_products.sort_values(by='promo_greater_with', inplace=True)

# %%
sorted_products.loc[sorted_products['promo_greater_with'] > 1000].head(50)
# Out:
#              sku                                               name  \
# 17992    PAC2281  Second hand - Apple iMac 20 "Core 2 Duo 226GHz...
# 17668    PAC2196  Second hand - Apple iMac 20 "Core 2 Duo 226GHz...
# 17667    PAC2195  Second hand - Apple iMac 20 "Core 2 Duo 226GHz...
# 17665    PAC2194  Second hand - Apple iMac 20 "Core 2 Duo 226GHz...
# 17705    PAC2200  Second hand - Apple iMac 20 "Core 2 Duo 226GHz...
# 17991    PAC2282  Second hand - Apple iMac 20 "Core 2 Duo 226GHz...
# 17704    PAC2198  Second hand - Apple iMac 20 "Core 2 Duo 226GHz...
# 16041    PAC2062  Second hand - Apple iMac 20 "Core 2 Duo 266GHz...
# 16039    PAC2063  Second hand - Apple iMac 20 "Core 2 Duo 266GHz...
# 14996    PAC1921  Second hand - Apple iMac 20 "Core 2 Duo 24GHz ...
# 15935    PAC2057  Second hand - Apple iMac 20 "Core 2 Duo 24GHz ...
# 15933    PAC2058  Second hand - Apple iMac 20 "Core 2 Duo 24GHz ...
# 14997    PAC1920  Second hand - Apple iMac 20 "Core 2 Duo 24GHz ...
# 18846    AP20067  Very Good - Apple iMac 20 "Core 2 Duo 226GHz |...
# 16005    PAC2066  Second hand - Apple iMac 20 "Core 2 Duo 226GHz...
# 15937    PAC2060  Second hand - Apple iMac 20 "Core 2 Duo 226GHz...
# 15962    PAC2064  Second hand - Apple iMac 20 "Core 2 Duo 266GHz...
# 15956    PAC2067  Second hand - Apple iMac 24 "Core 2 Duo 28 GHz...
# 16035    PAC2070  Second hand - Apple iMac 20 "Core 2 Duo 266GHz...
# 16008    PAC2071  Second hand - Apple iMac 24 "Core 2 Duo 28 GHz...
# 17338    APP2466  The 1st Gen. 42mm Apple Watch Stainless Steel ...
# 17337    APP2465  Apple Watch the 1st Gen. 42mm Case Stainless s...
# 17339    APP2467  Apple Watch the 1st Gen. 38mm Case Stainless s...
# 17340    APP2468  The 1st Gen. 38mm Apple Watch Stainless Steel ...
# 17989    PAC2284  Second hand - Apple iMac 215 "Core i3 306GHz |...
# 17988    PAC2283  Second hand - Apple iMac 215 "Core i3 306GHz |...
# 16007    PAC2068  Second hand - Apple iMac 21.5 "Core i3 306GHz ...
# 17386    OWC0229                     OWC Mercury Electra 6G SSD 2TB
# 14703    PAC1764                                   QNAP TS-431P NAS
# 1357     PAC0592  Apple Mac mini Core i5 14GHz | 4GB RAM | 500GB...
# 11748    PAC1680      QNAP TS-228 | 20TB (2x10TB) Seagate Iron Wolf
# 14998    PAC1933  Second hand - Apple iMac 215 "Core i5 Quad-Cor...
# 17615    PAC2354  DS418J Synology NAS Server | 16TB (4x4TB) Seag...
# 16013    AP20097  Like new - Apple iPad Pro 12.9 "Wi-Fi 128GB Sp...
# 17151    AP20227   Like new - Apple iPad Pro 12.9 "Wi-Fi 128GB Gold
# 13180    PAC1685  Pack QNAP TS-251A NAS Server | 2GB RAM | Seaga...
# 14984    PAC1922  Second hand - Apple iMac 215 "Core i5 Quad-Cor...
# 16006    AP20016  Second hand - Apple iMac 215 "Core i5 Quad-Cor...
# 15961    PAC2069  Second hand - Apple iMac 215 "Core i5 Quad-Cor...
# 11196    PAC1640   Pack QNAP TS-253A | 4G RAM | 6TB Seagate Desktop
# 11197    PAC1640   Pack QNAP TS-253A | 4G RAM | 6TB Seagate Desktop
# 11796    PAC1842   Synology DS216J | 20TB (2x10TB) Seagate IronWolf
# 11795    PAC1842   Synology DS216J | 20TB (2x10TB) Seagate IronWolf
# 15951  WAC0222-A    Open - Wacom Cintiq graphics tablet Pro 13 "FHD
# 11055    PAC1387  Pack QNAP TS-251 + | 2GB RAM | Seagate 16TB Ir...
# 17824    PAC2337  Synology DS718 + NAS Server | 10GB RAM | 8TB (...
# 17874    PAC2364  Synology DS218 + NAS Server | 2GB RAM | 16TB (...
# 17000    PAC2172  QNAP TS-251A-4G NAS Server | 4GB RAM | 16TB (2...
# 15697    PAC1938  Second hand - Apple iMac 215 "Core i5 Quad-Cor...
# 17257    AP20296  Apple MacBook Air 13 "Core i5 16GHz | 4GB RAM ...
#
#                                                     desc    price  \
# 17992  Refurbished iMac 20 inch Core 2 Duo | 2GB RAM ...  1499.00
# 17668  Refurbished iMac 20 inch Core 2 Duo | 2GB RAM ...  1199.00
# 17667  Refurbished iMac 20 inch Core 2 Duo | 2GB RAM ...  1199.00
# 17665  Refurbished iMac 20 inch Core 2 Duo | 2GB RAM ...  1199.00
# 17705  Refurbished iMac 20 inch Core 2 Duo | 2GB RAM ...  1199.00
# 17991  Refurbished iMac 20 inch Core 2 Duo | 2GB RAM ...  1199.00
# 17704  Refurbished iMac 20 inch Core 2 Duo | 2GB RAM ...  1199.00
# 16041  IMac used 20 inch Core 2 Duo 266GHz | 4GB RAM ...  1499.00
# 16039  Refurbished iMac 20 inch Core 2 Duo 266GHz | 4...  1499.00
# 14996  IMac used 20 inch Core 2 Duo 24GHz | 3GB RAM |...  1199.00
# 15935  Refurbished iMac 20 inch Core 2 Duo 24GHz | 4G...  1499.00
# 15933  Refurbished iMac 20 inch Core 2 Duo 24GHz | 2G...  1199.00
# 14997  IMac used 20 inch Core 2 Duo 24GHz | 2GB RAM |...  1199.00
# 18846  Refurbished iMac 20 inch Core 2 Duo 226GHz | 2...  1199.00
# 16005  Refurbished iMac 20 inch Core 2 Duo | 4GB RAM ...  1199.00
# 15937  Refurbished iMac 20 inch Core 2 Duo 226GHz | 4...  1199.00
# 15962  IMac used 20 inch Core 2 Duo 266GHz | 4GB RAM ...  1199.00
# 15956  Computer Refurbished iMac 24 inch Core 2 Duo 2...  1799.00
# 16035  Refurbished iMac 20 inch Core 2 Duo 266GHz | 4...  1199.00
# 16008  Computer Refurbished iMac 24 inch Core 2 Duo 2...  1799.00
# 17338  Apple Watch the 1st gene. touch screen monitor...  1269.00
# 17337  Apple Watch the 1st gene. touch screen monitor...  1269.00
# 17339  Apple Watch the 1st gene. touch screen monitor...  1219.00
# 17340  Apple Watch the 1st gene. touch screen monitor...  1219.00
# 17989  Computer Refurbished iMac Core i3 215 inches 3...  1199.00
# 17988  Computer Refurbished iMac Core i3 215 inches 3...  1199.00
# 16007  Computer Refurbished iMac Core i3 215 inches 3...  1199.00
# 17386                  2TB HDD SATA III SSD 7mm for Mac.  1004.99
# 14703  NAS with 16TB capacity Seagate Hard Drives for...  1021.95
# 1357   PC Mac mini Core i5 4GB 500GB Flash 14GHz (MGE...  1015.59
# 11748  NAS + 20TB (2x10TB) Seagate Iron Wolf for Mac ...  1340.97
# 14998  Computer Refurbished iMac Core i5 215 inches 2...  1199.00
# 17615  4 bay NAS server capable of transmitting H.265...  1034.95
# 16013  iPad Pro 12.9 inch Wi-Fi 128GB Reconditioned G...  1009.00
# 17151  iPad Pro 12.9 inch Wi-Fi 128GB Reconditioned C...  1009.00
# 13180  NAS with 2GB of RAM and 16TB (2x8TB) Seagate I...  1069.67
# 14984  IMac used 215 inch i5 25GHz | 4GB RAM | 500GB ...  1199.00
# 16006  IMac used i5 215 inch quad-core 25GHz | 8GB RA...  1199.00
# 15961  215 inch iMac reconditioned i5 quad-core 25GHz...  1199.00
# 11196  QNAP NAS + 4GB memory RAM + 16TB (2x8TB) Seaga...  1109.97
# 11197  QNAP NAS + 4GB memory RAM + 16TB (2x8TB) Seaga...  1109.97
# 11796  NAS server with 20TB capacity (2x10TB) Seagate...  1375.97
# 11795  NAS server with 20TB capacity (2x10TB) Seagate...  1375.97
# 15951  graphics tablet 13-inch FHD resolution (1920x1...  1099.90
# 11055  Nas QNAP TS-251 + 2GB RAM memory + 16TB (2x8TB...  1068.98
# 17824  Scalable NAS server with transcoding 4K: 4-cor...  1126.33
# 17874  NAS storage server integrated with special foc...  1064.97
# 17000  NAS with 4GB of RAM and two hard disks 8TB (2x...  1118.07
# 15697  Computer Refurbished iMac Core i5 215 inches 2...  1199.00
# 17257  Computer Refurbished MacBook Air 13-inch i5 16...  1099.00
#
#        promo_price  in_stock      type  is_promo_price_greater  \
# 17992     2555.945         0  5,43E+15                    True
# 17668     2555.945         0  5,43E+15                    True
# 17667     2555.945         0  5,43E+15                    True
# 17665     2555.945         0  5,43E+15                    True
# 17705     2555.945         0  5,43E+15                    True
# 17991     2555.945         0  5,43E+15                    True
# 17704     2755.944         0  5,43E+15                    True
# 16041     3355.948         0  51882158                    True
# 16039     3455.949         0  51882158                    True
# 14996     3255.844         0      1282                    True
# 15935     3555.944         0  5,43E+15                    True
# 15933     3265.844         0  5,43E+15                    True
# 14997     3365.845         0  5,43E+15                    True
# 18846     3755.949         0  5,43E+15                    True
# 16005     3790.003         0  5,43E+15                    True
# 15937     3955.949         0  51882158                    True
# 15962     4189.994         0  51882158                    True
# 15956     4855.949         0      1282                    True
# 16035     4289.996         0      1282                    True
# 16008     4889.998         0      1282                    True
# 17338     4990.004         0  24895185                    True
# 17337     4990.004         0  24895185                    True
# 17339     4990.004         0  24885185                    True
# 17340     4990.004         0  24885185                    True
# 17989     6135.945         0  5,72E+15                    True
# 17988     6455.945         0  5,72E+15                    True
# 16007     6490.006         0      1282                    True
# 17386     6619.934         0  12215397                    True
# 14703     6913.686         0  12175397                    True
# 1357      6920.044         0      1282                    True
# 11748     7261.791         0  12175397                    True
# 14998     7289.951         0  5,72E+15                    True
# 17615     7339.896         0  12175397                    True
# 16013     7328.111         0  51861714                    True
# 17151     7328.111         0  51861714                    True
# 13180     7511.789         0  12175397                    True
# 14984     7755.846         0      1282                    True
# 16006     7765.841         0      1282                    True
# 15961     7790.047         0      1282                    True
# 11196     7751.792         1  12175397                    True
# 11197     7751.792         1  12175397                    True
# 11796     8051.788         0  12175397                    True
# 11795     8051.788         0  12175397                    True
# 15951     7785.395         0      1298                    True
# 11055     7771.794         1  12175397                    True
# 17824     7851.787         0  12175397                    True
# 17874     7791.795         1  12175397                    True
# 17000     7871.788         1  12175397                    True
# 15697     7999.894         0  5,72E+15                    True
# 17257     7905.946         0  2,17E+11                    True
#
#        promo_greater_with
# 17992            1056.945
# 17668            1356.945
# 17667            1356.945
# 17665            1356.945
# 17705            1356.945
# 17991            1356.945
# 17704            1556.944
# 16041            1856.948
# 16039            1956.949
# 14996            2056.844
# 15935            2056.944
# 15933            2066.844
# 14997            2166.845
# 18846            2556.949
# 16005            2591.003
# 15937            2756.949
# 15962            2990.994
# 15956            3056.949
# 16035            3090.996
# 16008            3090.998
# 17338            3721.004
# 17337            3721.004
# 17339            3771.004
# 17340            3771.004
# 17989            4936.945
# 17988            5256.945
# 16007            5291.006
# 17386            5614.944
# 14703            5891.736
# 1357             5904.454
# 11748            5920.821
# 14998            6090.951
# 17615            6304.946
# 16013            6319.111
# 17151            6319.111
# 13180            6442.119
# 14984            6556.846
# 16006            6566.841
# 15961            6591.047
# 11196            6641.822
# 11197            6641.822
# 11796            6675.818
# 11795            6675.818
# 15951            6685.495
# 11055            6702.814
# 17824            6725.457
# 17874            6726.825
# 17000            6753.718
# 15697            6800.894
# 17257            6806.946

# %% [markdown]
# Till now confirm that.

# %%
sorted_products.loc[sorted_products['promo_greater_with'] > 500].head(50)
# Out:
#              sku                                               name  \
# 16958  NTE0019-A  Open - NewerTech Voyager Q HDD Dock FW800 / 40...
# 15132  PLA0014-A  Open - Plantronics Backbeat Fit Green Wireless...
# 433      NTE0025  NewerTech Voyager Q HDD Dock FW800 / 400 / USB...
# 18718  MAT0003-A  Open - Matias Bluetooth keyboard and numeric S...
# 2322     MOP0065  Mophie Juice Pack Plus Battery Case (3300 mAh)...
# 14450  MOP0058-A  (Open) Mophie Juice Pack Plus Battery Case (33...
# 1056     MOP0056  Mophie Space Pack Battery Case (1700mAh) and S...
# 13121    TPL0034  TP-Link TL-PA8010P Kit 1 Port Gigabit Powerlin...
# 13681  LIF0095-A  Open - Lifeproof nüüd Waterproof Case iPad Min...
# 15005  WIT0017-A           Open - Withings Activite POP Black Clock
# 19231  STA0035-A  Open - Startech USB Hub-C or VGA to HDMI 4K US...
# 18991  LAC0174-A  Open - LaCie Porsche Design Mobile Hard Drive ...
# 14821  PEB0003-A                Open - Pebble Smartwatch Time Black
# 18794  STA0033-A  Open - Hub Startech USB to VGA DVI-C Mini Disp...
# 19004  NTE0011-A  Open - NewerTech NuPower Battery MacBook 13 "w...
# 16099    AP20121  Second hand - Smart Battery Apple iPhone Batte...
# 14803  LIF0061-A  Open - Lifeproof nüüd Waterproof Case Black iP...
# 18938  SEA0096-A           Open - Seagate Barracuda 2TB HDD 25 "7mm
# 11606    PLA0021  Plantronics Backbeat Sense Bluetooth Headset W...
# 11522    HER0020    Experience BT02 Hercules Wireless Speaker White
# 17567    AP20299  Like new - Apple Smart Cover with Keyboard Eng...
# 14452  WAC0172-A  (Open) Wacom Bamboo tablet Spark sleeve up to ...
# 15083  WAC0170-A    Open - Wacom Bamboo Spark snap-fit ​​iPad Air 2
# 17652  KEN0239-A  Open - Kensington USB Dock SD1500-C to USB 3.0...
# 2321     MOP0064  Mophie Juice Pack Plus Battery Case (3300 mAh)...
# 2989     WAC0176           Wacom Bamboo Spark snap-fit ​​iPad Air 2
# 1079     BLM0012  Blue Microphones Snowball USB Microphone Black...
# 472      NTE0038        NewerTech NuPower battery PowerBook G4 17 "
# 14487    SEA0102           Seagate Barracuda 2TB Hard Drive 25 "7mm
# 15310  DLK0089-A      Open - D-Link DNS-320-L NAS server Mac and PC
# 14686    SEA0108         Seagate 2TB NAS Hard Drive IronWolf SATA 3
# 11710    PEB0009                       Pebble Smartwatch Time Black
# 11479    PAC1248  Pack Apple Siri Griffin Survivor Case + Remote...
# 13726    PAR0067            Swing Parrot Minidrone + command FLYPAD
# 13221  LIF0089-A  (Open) Lifeproof Fre Power 2600mAh Battery Cas...
# 3145     JBL0107                 JBL Flip 3 Bluetooth Speaker Black
# 2763     BOS0028                 Bose Headphones White IE SoundTrue
# 15809  IFX0150-A  Open - iFixit battery Macbook Air 13 "Early 20...
# 407      PAC0271  OWC Mercury On-The-Go Pro Mini Hard Drive 1TB ...
# 15134  TPL0027-A  Open - TP-Link TL-PA8030P Kit 3 Port Gigabit P...
# 15135  DLK0051-A  Open - D-Link DCS-825L camera Babycam Wi-Fi ba...
# 15577  LOG0186-A  Open - Ultimate Ears Boom 2 Bluetooth Portable...
# 1878   NTE0056-A  Open - NewerTech NuPower Battery 65W MacBook P...
# 16964  IKM0056-A  Open - IK Multimedia iRig Guitar Interface 96k...
# 2107     IHE0011              Pack iHealth scale + Activity Monitor
# 2320     MOP0063  Mophie Juice Pack Plus Battery Case (3300 mAh)...
# 17046    AP20199  Like new - Apple Smart Battery Battery Case iP...
# 17565    AP20343  Like new - Apple Smart Battery iPhone Battery ...
# 17223    AP20269  Like new - Apple Smart Battery Battery Case iP...
# 11108  SEA0038-A  Open - Seagate Barracuda 3TB 35 "SATA 7200rpm ...
#
#                                                     desc   price  promo_price  \
# 16958  Dock disc 25 inch and 35 inch FW800 / 400 / US...  108.99      609.294
# 15132  Bluetooth sports headset with microphone and w...  129.99      643.593
# 433    Dock disc 25 inch and 35 inch FW800 / 400 / US...  108.99      626.901
# 18718  Refurbished Bluetooth keyboard aluminum numeri...  119.99      651.044
# 2322   Case 3300 mAh battery and LED indicator for iP...  129.99      669.856
# 14450  Case 3300 mAh battery and LED indicator for iP...  129.99      670.877
# 1056   Housing with battery and 16GB external storage...  149.99      699.864
# 13121  amplifier with fast speed internet plug kit in...  119.79      669.892
# 13681  Waterproof protective cover and extreme condit...  109.99      671.868
# 15005  Smartwatch that records sleep and movement for...  149.90      717.738
# 19231  Hub with USB-C connection VGA port or HDMI 4K ...  123.99      692.247
# 18991  External Hard Drive 1TB USB refitted-C and USB...  104.99      681.379
# 14821  Bluetooth watch intelligent microphone and sim...  169.95      748.604
# 18794  Hub Thunderbolt connection refitted with 3 / U...  128.99      715.811
# 19004  MacBook battery 133 inches (White Model) open box  119.99      709.187
# 16099  Reconditioned Case with battery for iPhone Res...  119.00      729.896
# 14803  Waterproof protective cover and extreme condit...  119.99      735.298
# 18938  Internal Hard Drive 2TB refitted 7mm and 25 fo...  129.99      746.743
# 11606  intelligent wireless headset and free Jack 3.5...  179.99      799.895
# 11522             25W Bluetooth speaker and 20h battery.  179.99      799.931
# 17567  Reconditioned cover keyboard support Apple Key...  179.00      799.931
# 14452                                  Bloc Smart notes.  159.90      789.311
# 15083                                  Bloc Smart notes.  159.90      789.311
# 17652  Refurbished Laptop Dock with 4 ports and 4K vi...  105.99      735.935
# 2321   Case 3300 mAh battery and LED indicator for iP...  129.99      769.899
# 2989                                   Bloc Smart notes.  159.90      799.895
# 1079   Professional microphone with USB connection fo...  107.99      749.898
# 472                    PowerBook G4 battery 17 inch 62W.  120.99      769.899
# 14487  Internal Hard Drive 2TB 7mm and 25 for Mac and PC  129.99      779.942
# 15310                    2-bay NAS server for Mac and PC  115.99      775.865
# 14686  NAS hard drive designed for systems with inter...  109.99      769.935
# 11710  Bluetooth watch intelligent microphone and sim...  169.95      829.903
# 11479  Pack Remote for Apple TV Media Player Apple Gr...  108.99      769.899
# 13726  Mini drone with autopilot vertical takeoff and...  139.00      799.931
# 13221  Submersible battery cover with water up to 2 m...  129.99      794.015
# 3145   Bluetooth wireless speaker for iPhone iPad and...  129.99      799.895
# 2763    Headphones great restraint iPhone iPod and iPad.  129.95      799.895
# 15809  Battery replacement Macbook 13 inch Mid 2012 t...  109.99      780.025
# 407    Pack outer box 25 inches + 1TB Hard Drive USB ...  184.98      855.845
# 15134  amplifier with fast speed internet plug kit in...  109.00      781.025
# 15135  DLink Camera baby monitors Baby EyeOn controll...  227.00      899.901
# 15577  Logitech Bluetooth speaker with waterproof Mic...  209.00      885.847
# 1878                 MacBook Pro 13 inch Battery 2009/14  131.99      809.662
# 16964  Guitar interface for recording high quality au...  121.99      799.895
# 2107   Pack Scale + Activity Monitor and dream App fo...  129.99      809.853
# 2320   Case 3300 mAh battery and LED indicator for iP...  129.99      809.853
# 17046     Reconditioned Battery Case for iPhone 6s and 6  119.00      799.895
# 17565      Reconditioned Battery Case for Apple iPhone 7  119.00      799.895
# 17223   Reacondicioando Battery Case for iPhone 6s and 6  119.00      799.895
# 11108  internal hard drive Mac and PC 3TB (ST3000DM001).  112.00      796.411
#
#        in_stock      type  is_promo_price_greater  promo_greater_with
# 16958         0      1298                    True             500.304
# 15132         0      1298                    True             513.603
# 433           0  12995397                    True             517.911
# 18718         0      5401                    True             531.054
# 2322          0  5,49E+11                    True             539.866
# 14450         0      1298                    True             540.887
# 1056          0  5,49E+11                    True             549.874
# 13121         0      1334                    True             550.102
# 13681         0      1298                    True             561.878
# 15005         0      1298                    True             567.838
# 19231         0  12585395                    True             568.257
# 18991         0  11935397                    True             576.389
# 14821         0      1298                    True             578.654
# 18794         0  12585395                    True             586.821
# 19004         0     10142                    True             589.197
# 16099         1  5,49E+11                    True             610.896
# 14803         0      1298                    True             615.308
# 18938         0  12655397                    True             616.753
# 11606         0      5384                    True             619.905
# 11522         0      5398                    True             619.941
# 17567         0      5403                    True             620.931
# 14452         0      1298                    True             629.411
# 15083         0      1298                    True             629.411
# 17652         0      1298                    True             629.945
# 2321          0  5,49E+11                    True             639.909
# 2989          0      1405                    True             639.995
# 1079          1      1375                    True             641.908
# 472           0  13005399                    True             648.909
# 14487         0  12655397                    True             649.952
# 15310         0      1298                    True             659.875
# 14686         1  12655397                    True             659.945
# 11710         0  11905404                    True             659.953
# 11479         1  54864259                    True             660.909
# 13726         1  11905404                    True             660.931
# 13221         0      1298                    True             664.025
# 3145          1      5398                    True             669.905
# 2763          0      5384                    True             669.945
# 15809         0      1298                    True             670.035
# 407           1  11935397                    True             670.865
# 15134         0      1298                    True             672.025
# 15135         0      1298                    True             672.901
# 15577         0      1298                    True             676.847
# 1878          0      1298                    True             677.672
# 16964         0      1298                    True             677.905
# 2107          0  11905404                    True             679.863
# 2320          0  5,49E+11                    True             679.863
# 17046         0  5,49E+11                    True             680.895
# 17565         0  5,49E+11                    True             680.895
# 17223         0  5,49E+11                    True             680.895
# 11108         0      1298                    True             684.411

# %% [markdown]
# Still confirm that.

# %%
sorted_products.loc[sorted_products['promo_greater_with'] > 250].head(50)
# Out:
#              sku                                               name  \
# 2345   ADN0016-A  Open - Adonit Jot Touch with PixelPoint pointe...
# 11626    JAW0039                 Jawbone UP2 Activity Monitor Plata
# 18989    PAC2507       Keyboard Replacement numerical Wireless iMac
# 12628  LIF0050-A  (Open) Lifeproof nüüd Waterproof Case iPad Min...
# 3036     PQI0008         IConnect PQI 64GB USB 3.0 Silver Lightning
# 2821   OWC0069-A  Open - OWC Envoy Pro USB 3.0 Case for MacBook ...
# 1863     RUT0009  Orbit runtastic fitness monitor activity and s...
# 1114     ADN0022  Adonit Jot Touch with PixelPoint pointer iPad ...
# 15530  LEX0028-A  Open - Lexar JumpDrive Lightning USB 3.0 C20i ...
# 84       IKM0013  IK Multimedia iRig MIX DJ Mixer iPhone iPad an...
# 2319     MOP0062  Mophie Juice Pack Air Case Battery (2750 mAh) ...
# 2315     MOP0061  Mophie Juice Pack Air Case Battery (2750 mAh) ...
# 12269    LEX0034  Lexar JumpDrive Lightning USB 3.0 C20i Pendriv...
# 913      PAC0391  OWC Data Doubler Pack MacBook / Macbook Pro Black
# 2308     MOP0060  Mophie Juice Pack Air Case Battery (2750 mAh) ...
# 12138    MOP0078  Mophie Juice Pack Air Case Battery (2750 mAh) ...
# 13741    JAW0047                  Jawbone UP2 Lila Activity Monitor
# 90       PAC0023        OWC Data Doubler Pack MacBook / MacBook Pro
# 15501  SAN0110-A  Open - Sandisk Wireless Connect Wireless Flash...
# 3135     NTE0100  NewerTech Guardian Maximus RAID mini FW800 / e...
# 571      OWC0075  OWC Envoy Pro USB 3.0 Case for MacBook Pro Retina
# 16970  MAT0001-A  Open - Matias Bluetooth keyboard Aluminum + Sp...
# 2828     JAW0040                 Jawbone UP3 Activity Monitor Black
# 2470     LIF0056  Lifeproof nüüd Case Waterproof iPad Mini / Ret...
# 14763    PAC1871  OWC Data Doubler Pack + External Enclosure Sli...
# 12496  SAN0083-A  (Open) iXpand SanDisk Flash Drive 64GB USB 2.0...
# 15662    PAC1927  Second hand - Apple iMac 20 "Core 2 Duo 226GHz...
# 16958  NTE0019-A  Open - NewerTech Voyager Q HDD Dock FW800 / 40...
# 15132  PLA0014-A  Open - Plantronics Backbeat Fit Green Wireless...
# 433      NTE0025  NewerTech Voyager Q HDD Dock FW800 / 400 / USB...
# 18718  MAT0003-A  Open - Matias Bluetooth keyboard and numeric S...
# 2322     MOP0065  Mophie Juice Pack Plus Battery Case (3300 mAh)...
# 14450  MOP0058-A  (Open) Mophie Juice Pack Plus Battery Case (33...
# 1056     MOP0056  Mophie Space Pack Battery Case (1700mAh) and S...
# 13121    TPL0034  TP-Link TL-PA8010P Kit 1 Port Gigabit Powerlin...
# 13681  LIF0095-A  Open - Lifeproof nüüd Waterproof Case iPad Min...
# 15005  WIT0017-A           Open - Withings Activite POP Black Clock
# 19231  STA0035-A  Open - Startech USB Hub-C or VGA to HDMI 4K US...
# 18991  LAC0174-A  Open - LaCie Porsche Design Mobile Hard Drive ...
# 14821  PEB0003-A                Open - Pebble Smartwatch Time Black
# 18794  STA0033-A  Open - Hub Startech USB to VGA DVI-C Mini Disp...
# 19004  NTE0011-A  Open - NewerTech NuPower Battery MacBook 13 "w...
# 16099    AP20121  Second hand - Smart Battery Apple iPhone Batte...
# 14803  LIF0061-A  Open - Lifeproof nüüd Waterproof Case Black iP...
# 18938  SEA0096-A           Open - Seagate Barracuda 2TB HDD 25 "7mm
# 11606    PLA0021  Plantronics Backbeat Sense Bluetooth Headset W...
# 11522    HER0020    Experience BT02 Hercules Wireless Speaker White
# 17567    AP20299  Like new - Apple Smart Cover with Keyboard Eng...
# 14452  WAC0172-A  (Open) Wacom Bamboo tablet Spark sleeve up to ...
# 15083  WAC0170-A    Open - Wacom Bamboo Spark snap-fit ​​iPad Air 2
#
#                                                     desc     price  \
# 2345          Special precision pointer to draw fine tip   119.000
# 11626  Bluetooth monitor activity and sleep with pers...   119.900
# 18989  Keyboard replacement service at the time of pu...   149.000
# 12628  Water resistant protective cover for iPad Mini...   109.990
# 3036   PenDrive 64GB USB 3.0 and Lightning for iPhone...   139.900
# 2821   Portable USB 3.0 External SSD box Retina MacBo...   118.990
# 1863   Bracelet sport and activity control sleep for ...   119.990
# 1114            Pointer with fine tip and precision IPAD   119.000
# 15530  Lightning to USB external memory for iPad and ...   108.900
# 84                        Dj mixer iPhone iPad and iPod.   121.990
# 2319   Case 2750 mAh battery and LED indicator for iP...   109.990
# 2315   Case 2750 mAh battery and LED indicator for iP...   109.990
# 12269  64GB external memory with Lightning to USB con...   108.900
# 913    Pack Replacement Superdrive for SSD / HDD + bo...   121.980
# 2308   Case 2750 mAh battery and LED indicator for iP...   109.990
# 12138  Case 2750 mAh battery and LED indicator for iP...   109.990
# 13741  Bluetooth monitor activity and sleep with pers...   119.990
# 90     Pack Replacement Superdrive for SSD / HDD + bo...   107.990
# 15501     Wireless Storage 128GB for iPhone / iPad / Mac   104.000
# 3135   Mini Raid system with FW800 / eSATA / USB conn...   120.990
# 571    Box Portable External USB 3.0 SSD for MacBook ...   118.990
# 16970  Aluminum Bluetooth keypad manages 4 devices si...   119.990
# 2828   Bluetooth activity monitor recorded sleep data...   179.990
# 2470   Water resistant protective cover for iPad Mini...   109.990
# 14763  Pack Pack Superdrive replacement SSD / HDD Ext...   107.990
# 12496  USB 2.0 Pen Drive and Lightning 64Gb iPad and ...   110.000
# 15662  IMac used 20 inch Core 2 Duo 226GHz | 2GB RAM ...  2360.303
# 16958  Dock disc 25 inch and 35 inch FW800 / 400 / US...   108.990
# 15132  Bluetooth sports headset with microphone and w...   129.990
# 433    Dock disc 25 inch and 35 inch FW800 / 400 / US...   108.990
# 18718  Refurbished Bluetooth keyboard aluminum numeri...   119.990
# 2322   Case 3300 mAh battery and LED indicator for iP...   129.990
# 14450  Case 3300 mAh battery and LED indicator for iP...   129.990
# 1056   Housing with battery and 16GB external storage...   149.990
# 13121  amplifier with fast speed internet plug kit in...   119.790
# 13681  Waterproof protective cover and extreme condit...   109.990
# 15005  Smartwatch that records sleep and movement for...   149.900
# 19231  Hub with USB-C connection VGA port or HDMI 4K ...   123.990
# 18991  External Hard Drive 1TB USB refitted-C and USB...   104.990
# 14821  Bluetooth watch intelligent microphone and sim...   169.950
# 18794  Hub Thunderbolt connection refitted with 3 / U...   128.990
# 19004  MacBook battery 133 inches (White Model) open box   119.990
# 16099  Reconditioned Case with battery for iPhone Res...   119.000
# 14803  Waterproof protective cover and extreme condit...   119.990
# 18938  Internal Hard Drive 2TB refitted 7mm and 25 fo...   129.990
# 11606  intelligent wireless headset and free Jack 3.5...   179.990
# 11522             25W Bluetooth speaker and 20h battery.   179.990
# 17567  Reconditioned cover keyboard support Apple Key...   179.000
# 14452                                  Bloc Smart notes.   159.900
# 15083                                  Bloc Smart notes.   159.900
#
#        promo_price  in_stock      type  is_promo_price_greater  \
# 2345       380.832         0      1298                    True
# 11626      399.905         0  11905404                    True
# 18989      499.899         1  13855401                    True
# 12628      471.427         0      1298                    True
# 3036       502.803         0  42945397                    True
# 2821       485.655         0      1298                    True
# 1863       499.899         0  11905404                    True
# 1114       499.899         0      1229                    True
# 15530      501.182         0      1298                    True
# 84         519.937         0  11905404                    True
# 2319       519.937         0  5,49E+11                    True
# 2315       519.937         0  5,49E+11                    True
# 12269      532.799         0  42945397                    True
# 913        559.903         1  12755395                    True
# 2308       548.977         0  5,49E+11                    True
# 12138      548.977         0  11865403                    True
# 13741      569.898         0  11905404                    True
# 90         559.903         1  12755395                    True
# 15501      562.051         0      1298                    True
# 3135       579.893         0  11935397                    True
# 571        599.906         0  11935397                    True
# 16970      602.921         0      1298                    True
# 2828       669.856         0  11905404                    True
# 2470       599.918         0  12635403                    True
# 14763      599.906         0  12755395                    True
# 12496      605.582         0      1298                    True
# 15662     2855.967         0      1282                    True
# 16958      609.294         0      1298                    True
# 15132      643.593         0      1298                    True
# 433        626.901         0  12995397                    True
# 18718      651.044         0      5401                    True
# 2322       669.856         0  5,49E+11                    True
# 14450      670.877         0      1298                    True
# 1056       699.864         0  5,49E+11                    True
# 13121      669.892         0      1334                    True
# 13681      671.868         0      1298                    True
# 15005      717.738         0      1298                    True
# 19231      692.247         0  12585395                    True
# 18991      681.379         0  11935397                    True
# 14821      748.604         0      1298                    True
# 18794      715.811         0  12585395                    True
# 19004      709.187         0     10142                    True
# 16099      729.896         1  5,49E+11                    True
# 14803      735.298         0      1298                    True
# 18938      746.743         0  12655397                    True
# 11606      799.895         0      5384                    True
# 11522      799.931         0      5398                    True
# 17567      799.931         0      5403                    True
# 14452      789.311         0      1298                    True
# 15083      789.311         0      1298                    True
#
#        promo_greater_with
# 2345              261.832
# 11626             280.005
# 18989             350.899
# 12628             361.437
# 3036              362.903
# 2821              366.665
# 1863              379.909
# 1114              380.899
# 15530             392.282
# 84                397.947
# 2319              409.947
# 2315              409.947
# 12269             423.899
# 913               437.923
# 2308              438.987
# 12138             438.987
# 13741             449.908
# 90                451.913
# 15501             458.051
# 3135              458.903
# 571               480.916
# 16970             482.931
# 2828              489.866
# 2470              489.928
# 14763             491.916
# 12496             495.582
# 15662             495.664
# 16958             500.304
# 15132             513.603
# 433               517.911
# 18718             531.054
# 2322              539.866
# 14450             540.887
# 1056              549.874
# 13121             550.102
# 13681             561.878
# 15005             567.838
# 19231             568.257
# 18991             576.389
# 14821             578.654
# 18794             586.821
# 19004             589.197
# 16099             610.896
# 14803             615.308
# 18938             616.753
# 11606             619.905
# 11522             619.941
# 17567             620.931
# 14452             629.411
# 15083             629.411

# %% [markdown]
# Still.

# %%
sorted_products.loc[sorted_products['promo_greater_with'] > 50].head(50)
# Out:
#              sku                                               name  \
# 2883     APP1096                         Apple iPod Touch 64GB Blue
# 2882     APP1093                         Apple iPod Touch 64GB Rosa
# 2881     APP1090                   Apple iPod Touch 64GB Space Gray
# 2879     APP1084                       Apple iPod Touch 64GB Silver
# 2880     APP1087                         Apple iPod Touch 64GB Gold
# 11189    PAC1655       QNAP TS-253A | 16GB RAM | 6TB (2x3TB) WD Red
# 11188    PAC1655       QNAP TS-253A | 16GB RAM | 6TB (2x3TB) WD Red
# 11339    KIN0153           Kingston DataTraveler G2 USB 3.0 8Gb SE9
# 10754  NTE0022-A           Open - NewerTech Mini DVI to VGA Adapter
# 13550    GRT0428         Griffin Reveal iPhone Case 8/7 Transparent
# 17346  NTE0021-A           Open - NewerTech Mini DVI to DVI Adapter
# 3087     BEL0186      Belkin Folio Case Classic iPhone 6 / 6S Black
# 642      MUV0108  Muvit Slim Case + Screen Protector iPhone 5C W...
# 1035     KEN0175  Kensington SafeGrip iPad Air Rugged Case with ...
# 2512   SPH0003-A  Open - Nubby Sphero robotic ball Sphero Case Blue
# 1899     SAN0035       SanDisk Ultra 16GB SDHC Memory Card Class 10
# 16117    AP20134  Second hand - Apple MagSafe to MagSafe convert...
# 12948  BEL0179-A  (Open) Classic Belkin Folio Case iPhone 6 / 6S...
# 10791    MOX0024  Housing Picto Women Moxie iPhone 6 / 6S Transp...
# 1781     JMO0070        Just Mobile Phone Case Skin AluFrame 6 Pink
# 1780     JMO0069       Just Mobile Phone Case Skin AluFrame 6 Beige
# 1777     JMO0066       Just AluFrame Mobile Phone Case Skin 6 Black
# 1797     KEN0195  Kensington Folio Case Cover Customize Me iPad ...
# 1040     OPU0009      Exo Opulus alcantara Case iPhone 5 / 5S black
# 12586    IFX0077                      iFixit iPhone Speaker 6 Piece
# 1620     MUV0154    Muvit timer for photos and audio control iPhone
# 1974     LEP0010  Lepow USB 3000mAh External Battery Moonstone B...
# 3086     BEL0184       Belkin Folio Case Classic iPhone 6 / 6S Blue
# 14586    SAT0031             Satechi-C USB Adapter USB-A Gray Space
# 2707     NTE0094             NewerTech Cable HDMI to HDMI 1.4A 180m
# 18151  SAT0004-A               Open - Satechi Aluminum Silver Mouse
# 16989  BEL0102-A  Open - Belkin 3 Cases iPhone Screen antihuella...
# 3019     ZAG0022  Zagg invisibleSHIELD Screen Protector Apple Wa...
# 14499  MUV0174-A  (Open) Muvit Crystal iPhone Case Bump 7 Black ...
# 14518  ZAG0023-A  (Open) Zagg Invisible Shield Glass Screen Prot...
# 14500  IFR0007-A  (Open) GlassGuard iFrogz iPhone Screen Saver 7...
# 13268    SHE0043      SwitchEasy iPhone 8/7 Plus NUMBERS Case Black
# 11374    BEZ0109                Be.ez LArobe Allure Black iPad Case
# 17296  TPL0032-A        Open - TP-LINK Cable 1m White Lightning IFM
# 12854    SAN0139            SanDisk SSD 480GB Plus 25 "SATA 6Gb / s
# 644      WDT0185         Red 750GB WD 25 "Mac PC hard drive and NAS
# 17287    TUC0336  Tucano Elements Second Skin Case MacBook Air 1...
# 3101     MUV0168       Muvit magnetic car holder iPhone Color Black
# 1251     TUC0175                   Tucano Fabric Case iPhone 6 Blue
# 15112  GRT0424-A  Open - Griffin Survivor iPhone Case Clear 7 Clear
# 12327  NTE0023-A          Open - NewerTech Mini DVI to HDMI Adapter
# 1177     MUV0137                   Muvit Minigel Lila iPhone 6 Case
# 1174     MUV0132            Muvit iPhone 6 Transparent Case Minigel
# 15666  OTT0137-A  Open - Otterbox Clearly Protected gel Case iPh...
# 18786  SHE0041-A  Open - SwitchEasy CoverBuddy Shell iPad Pro 97...
#
#                                                     desc     price  \
# 2883   New 6th generation iPod Touch 64GB with 8 mega...   292.810
# 2882   New 6th generation iPod Touch 64GB with 8 mega...   292.810
# 2881   New 6th generation iPod Touch 64GB with 8 mega...   292.810
# 2879   New 6th generation iPod Touch 64GB with 8 mega...   292.810
# 2880   New 6th generation iPod Touch 64GB with 8 mega...   292.810
# 11189  NAS with 16GB of RAM + memory 6TB (2x3TB) Netw...  7860.782
# 11188  NAS with 16GB of RAM + memory 6TB (2x3TB) Netw...  7860.782
# 11339           8GB USB 3.0 flash drive light and small.    15.990
# 10754                                   Mini DVI to VGA.    18.990
# 13550  thin polycarbonate case with transparent back ...    16.990
# 17346                            Adapter mini DVI to DVI    18.990
# 3087   Protective cover book format with microfiber i...    29.900
# 642          Slim Case + Screen Protector for iPhone 5C.    13.990
# 1035            Shockproof housing with handle for iPad.    43.990
# 2512                      Protective Case for Sphero 2.0    15.990
# 1899                              16GB SDHC memory card.    14.000
# 16117  Converter Apple MagSafe connector refitted to ...    12.000
# 12948  protective case with microfiber interior iPhon...    29.900
# 10791                           Cover for iPhone 6 / 6S.    19.990
# 1781                      Aluminum and leather iPhone 6.    39.990
# 1780                      Aluminum and leather iPhone 6.    39.990
# 1777                      Aluminum and leather iPhone 6.    39.990
# 1797   customizable cover with book closure type for ...    39.990
# 1040   Case for iPhone 5 / 5S polycarbonate and micro...    39.990
# 12586                               Speaker for iPhone 6    19.950
# 1620   Trigger for photos and Bluetooth audio driver ...    29.950
# 1974   USB external battery charging mode dual small ...    39.990
# 3086   protective case with microfiber interior for i...    29.900
# 14586  USB Adapter USB 3.0 A-C with compact and light...    18.000
# 2707                      HDMI to HDMI Cable 180 meters.    17.990
# 18151  Aluminum mat with ultra soft non-slip surface ...    29.990
# 16989  Set of 3 Screen Protectors for iPhone SE / 5s / 5    12.990
# 3019                   Screen Protector for Apple Watch.    16.990
# 14499  protective case with black bumper and rear tra...    13.950
# 14518  Protector Ultra soft edges beveled tempered gl...    19.990
# 14500  Screen Saver tempered glass with easy applicat...    19.990
# 13268       Ultra Thin Case for iPhone touch buttons 8/7    14.990
# 11374                   IPad Case flexible polyurethane.    34.950
# 17296  USB charging cable and Lightning 1 meter long ...    12.990
# 12854                           Hard SSD 480GB 25 inches  1499.892
# 644    Western Digital hard drive designed for NAS 75...   639.896
# 17287  Neoprene 4mm thick and interior velvet MacBook...    29.900
# 3101          Rotary Car Holder for any model of iPhone.    12.950
# 1251       Cover for iPhone 6 ultra light polycarbonate.    12.900
# 15112  Resistant polycarbonate transparent cover for ...    24.990
# 12327                 NewerTech Mini DVI to HDMI Adapter    21.990
# 1177               Softgel casing iPhone 6 of 47 inches.    11.990
# 1174               Softgel casing iPhone 6 of 47 inches.    11.990
# 15666  transparent cover and a flexible piece TPU for...    19.990
# 18786  Case reaconicionada rigid polycarbonate with p...    29.990
#
#        promo_price  in_stock      type  is_promo_price_greater  \
# 2883      342.8112         0  11821715                    True
# 2882      342.8112         0  11821715                    True
# 2881      342.8112         0  11821715                    True
# 2879      342.8112         0  11821715                    True
# 2880      342.8112         0  11821715                    True
# 11189    7911.7910         1  12175397                    True
# 11188    7911.7910         1  12175397                    True
# 11339      67.7960         0  57445397                    True
# 10754      71.2630         0      1298                    True
# 13550      69.9020         0  11865403                    True
# 17346      72.4730         0      1298                    True
# 3087       85.0030         0  11865403                    True
# 642        69.9380         0  11865403                    True
# 1035       99.9460         0  12635403                    True
# 2512       72.1110         0      1298                    True
# 1899       70.9060         0       NaN                    True
# 16117      69.9020         0  12585395                    True
# 12948      89.1580         0      1298                    True
# 10791      79.8960         0  11865403                    True
# 1781       99.8980         1  11865403                    True
# 1780       99.8980         0  11865403                    True
# 1777       99.8980         0  11865403                    True
# 1797       99.8980         0  12635403                    True
# 1040       99.8980         0  11865403                    True
# 12586      79.8960         0  21485407                    True
# 1620       89.9030         0  11905404                    True
# 1974       99.9460         0      1515                    True
# 3086       89.9030         0  11865403                    True
# 14586      79.8960         1  12585395                    True
# 2707       79.8960         1      1325                    True
# 18151      91.9380         0      1387                    True
# 16989      75.1470         0      1298                    True
# 3019       79.8960         1      2425                    True
# 14499      77.4880         0      1298                    True
# 14518      84.8210         0      1298                    True
# 14500      84.8220         0      1298                    True
# 13268      79.8960         0  11865403                    True
# 11374      99.9460         0  12635403                    True
# 17296      77.9950         0      1298                    True
# 12854    1565.8370         0  12215397                    True
# 644       705.8410         0  12655397                    True
# 17287      95.9170         0  13835403                    True
# 3101       79.8960         0      5720                    True
# 1251       79.8960         0  11865403                    True
# 15112      92.3420         0      1298                    True
# 12327      89.6670         0      1298                    True
# 1177       79.8960         0  11865403                    True
# 1174       79.8960         0  11865403                    True
# 15666      88.3660         0      1298                    True
# 18786      98.4130         0  12635403                    True
#
#        promo_greater_with
# 2883              50.0012
# 2882              50.0012
# 2881              50.0012
# 2879              50.0012
# 2880              50.0012
# 11189             51.0090
# 11188             51.0090
# 11339             51.8060
# 10754             52.2730
# 13550             52.9120
# 17346             53.4830
# 3087              55.1030
# 642               55.9480
# 1035              55.9560
# 2512              56.1210
# 1899              56.9060
# 16117             57.9020
# 12948             59.2580
# 10791             59.9060
# 1781              59.9080
# 1780              59.9080
# 1777              59.9080
# 1797              59.9080
# 1040              59.9080
# 12586             59.9460
# 1620              59.9530
# 1974              59.9560
# 3086              60.0030
# 14586             61.8960
# 2707              61.9060
# 18151             61.9480
# 16989             62.1570
# 3019              62.9060
# 14499             63.5380
# 14518             64.8310
# 14500             64.8320
# 13268             64.9060
# 11374             64.9960
# 17296             65.0050
# 12854             65.9450
# 644               65.9450
# 17287             66.0170
# 3101              66.9460
# 1251              66.9960
# 15112             67.3520
# 12327             67.6770
# 1177              67.9060
# 1174              67.9060
# 15666             68.3760
# 18786             68.4230

# %% [markdown]
# My conclusion is:
# - for the difference between 'promo_price' and 'price', grater than 500 is only a decimal problem.
# - for the difference smaller than 500, also most of them is only a decimal problem, but we have some products with 'price' with more than 4 figures, that the dot logic cannot work.

# %%
(products['promo_greater_with'] > 18.9012).value_counts()
# Out:
# False    18535
# True       745
# Name: promo_greater_with, dtype: int64

# %% [markdown]
# #### Sample test function

# %%
products_test = pd.DataFrame({'price': ['10.01', '11.01', '12.01'], 
                              'promo_price': ['100.2', '110.2', '120.2'],
                              'promo_greater_with': [90.19,99.19,108.19]})

# %%
products_test
# Out:
#    price promo_price  promo_greater_with
# 0  10.01       100.2               90.19
# 1  11.01       110.2               99.19
# 2  12.01       120.2              108.19

# %%
def modify_promo_price_2_sample(row):
    price = row['price']
    promo_price = row['promo_price']
    promo_greater_with = row['promo_greater_with']
    if promo_greater_with > 90:
        # Extract the integer and decimal parts of the promo_price
        int_part, dec_part = re.match(r'(\d+)\.(\d+)', promo_price).groups()
        # Reassemble the promo_price with the decimal point moved one place to the left
        if len(int_part) < 4:
            magic = len(int_part) - 1
            promo_price = '{}.{}{}'.format(int_part[:magic], int_part[magic:], dec_part[0:])
    return promo_price

# %%
products_test['promo_price'] = products_test.apply(modify_promo_price_2_sample, axis=1)

# %%
products_test
# Out:
#    price promo_price  promo_greater_with
# 0  10.01       10.02               90.19
# 1  11.01       11.02               99.19
# 2  12.01       12.02              108.19

# %% [markdown]
# #### Modify promo price again

# %% [markdown]
# ##### First let's do the job for everything grater than 500

# %%
def modify_promo_price_with_grather_condition(row):
    price = row['price']
    promo_price = row['promo_price']
    promo_greater_with = row['promo_greater_with']
    if promo_greater_with > 500:
        # Extract the integer and decimal parts of the promo_price
        int_part, dec_part = re.match(r'(\d+)\.(\d+)', promo_price).groups()
        # Reassemble the promo_price with the decimal point moved one place to the left
        magic = len(int_part) - 1
        promo_price = '{}.{}{}'.format(int_part[:magic], int_part[magic:], dec_part[0:])
    return promo_price

# %%
products = products.astype({"promo_price": 'str', "price": 'str'})

# %%
products['promo_price'] = products.apply(modify_promo_price_with_grather_condition, axis=1)

# %%
products['promo_price'] = pd.to_numeric(products['promo_price'])
products['price'] = pd.to_numeric(products['price'])

# %% [markdown]
# #### Verify what we have now.

# %%
products['promo_greater_with'] = products.apply(promo_greater_with, axis=1)

# %%
# Apply the custom function to each row of the dataframe
products['is_promo_price_greater'] = products.apply(check_price, axis=1)

# %%
products['is_promo_price_greater'].value_counts()
# Out:
# False    18635
# True       645
# Name: is_promo_price_greater, dtype: int64

# %%
sorted_products = products.copy()
sorted_products.sort_values(by='promo_greater_with', inplace=True)

# %%
sorted_products.loc[sorted_products['promo_greater_with'] > 50].head(10)

# %% [markdown]
# ##### Let's do the job for everything grater than 50, but excepting the prices with 4 figures

# %%
def modify_promo_price_with_grather_condition2(row):
    price = row['price']
    promo_price = row['promo_price']
    promo_greater_with = row['promo_greater_with']
    if promo_greater_with > 50:
        # Extract the integer and decimal parts of the promo_price
        int_part, dec_part = re.match(r'(\d+)\.(\d+)', promo_price).groups()
        # Reassemble the promo_price with the decimal point moved one place to the left
        if len(int_part) < 4:
            magic = len(int_part) - 1
            promo_price = '{}.{}{}'.format(int_part[:magic], int_part[magic:], dec_part[0:])
    return promo_price

# %%
products = products.astype({"promo_price": 'str', "price": 'str'})

# %%
products['promo_price'] = products.apply(modify_promo_price_with_grather_condition2, axis=1)

# %%
products['promo_price'] = pd.to_numeric(products['promo_price'])
products['price'] = pd.to_numeric(products['price'])

# %% [markdown]
# #### Verify what we got

# %%
products['promo_greater_with'] = products.apply(promo_greater_with, axis=1)
# Apply the custom function to each row of the dataframe
products['is_promo_price_greater'] = products.apply(check_price, axis=1)
products['is_promo_price_greater'].value_counts()
# Out:
# False    18817
# True       463
# Name: is_promo_price_greater, dtype: int64

# %%
sorted_products = products.copy()
sorted_products.sort_values(by='promo_greater_with', inplace=True)

# %%
sorted_products.loc[sorted_products['promo_greater_with'] > 50]
# Out:
#            sku                                               name  \
# 11188  PAC1655       QNAP TS-253A | 16GB RAM | 6TB (2x3TB) WD Red
# 11189  PAC1655       QNAP TS-253A | 16GB RAM | 6TB (2x3TB) WD Red
# 12854  SAN0139            SanDisk SSD 480GB Plus 25 "SATA 6Gb / s
# 11258  PAC1675          QNAP TS-453A | 16GB | 12TB (4x3TB) WD Red
# 12880  PAC2037                      Synology DS216 + II | 8GB RAM
# 14719  QNA0190  QNAP TVS-871U-RP NAS Server | Core i5 | 8GB RA...
# 12868  PAC2025                      Synology DS216 + II | 2GB RAM
# 15111  EIZ0022  CS2730 Monitor Eizo ColorEdge 27 "QHD AdobeRGB...
# 14716  QNA0187  QNAP TVS-1271U-RP NAS server with redundant po...
# 14717  QNA0188  QNAP TVS-1271U-RP NAS server with redundant po...
# 14718  QNA0189        QNAP TVS-1271U-RP NAS with redundant source
# 15662  PAC1927  Second hand - Apple iMac 20 "Core 2 Duo 226GHz...
#
#                                                     desc      price  \
# 11188  NAS with 16GB of RAM + memory 6TB (2x3TB) Netw...   7860.782
# 11189  NAS with 16GB of RAM + memory 6TB (2x3TB) Netw...   7860.782
# 12854                           Hard SSD 480GB 25 inches   1499.892
# 11258  QNAP NAS TS-453A with 16GB of RAM memory + 12T...  11892.782
# 12880  NAS with 4K transcoding and direct copy button...   5079.696
# 14719          NAS system format rack 8 bays and 8GB RAM   2418.790
# 12868  NAS with 4K transcoding and direct copy button...   3739.696
# 15111  Professional monitor for color management Adob...   1034.990
# 14716  Expansion unit rack format with 12 bays and 32 GB   3386.790
# 14717  Expansion unit rack bays 12 and format memory ...   2781.790
# 14718  Expansion unit rack bays 12 format and 8GB of ...   2346.190
# 15662  IMac used 20 inch Core 2 Duo 226GHz | 2GB RAM ...   2360.303
#
#        promo_price  in_stock      type  is_promo_price_greater  \
# 11188    7911.7910         1  12175397                    True
# 11189    7911.7910         1  12175397                    True
# 12854    1565.8370         0  12215397                    True
# 11258   11963.6810         1  12175397                    True
# 12880    5151.7930         0  12175397                    True
# 14719    2538.9902         0  12175397                    True
# 12868    3861.7880         0  12175397                    True
# 15111    1209.9879         1      1296                    True
# 14716    3567.9899         0  12175397                    True
# 14717    2962.9899         0  12175397                    True
# 14718    2538.9902         0  12175397                    True
# 15662    2855.9670         0      1282                    True
#
#        promo_greater_with
# 11188             51.0090
# 11189             51.0090
# 12854             65.9450
# 11258             70.8990
# 12880             72.0970
# 14719            120.2002
# 12868            122.0920
# 15111            174.9979
# 14716            181.1999
# 14717            181.1999
# 14718            192.8002
# 15662            495.6640

# %% [markdown]
# Look's good, I will let it like this.

# %% [markdown]
# ### Save the clean data.

# %%
# path for clean data
path_clean_data = "C:/Users/ruben/local_repos/WBS/Data_Science/Section_3/Data_Cleaning_Storytelling_with_Pandas_and_Matplotlib/data/clean_data/"

# %%
orders.to_csv(path_clean_data + "orders_cl.csv", index=False)

# %%
orderlines.to_csv(path_clean_data + "orderlines_cl.csv", index=False)

# %%
products.to_csv(path_clean_data + "products_cl.csv", index=False)
